# %%
import numpy as np
import pandas as pd

import os
import pickle
import re

import gzip
import json
import shutil

import random

# %%
data_dir = "./data"
reviews_fn = "Electronics.csv"
metadata_fn = "meta_Electronics.jsonl"
metadata_split = "meta/"
reviews_split = "reviews/"

# %% [markdown]
# # Preprocess metadata file

# %%
def split_jsonl(input_file, output_folder, num_files):
	if os.path.isdir(output_folder):
		shutil.rmtree(output_folder)

	if not os.path.exists(output_folder):
		os.makedirs(output_folder)

	with open(input_file, 'r', encoding='utf-8') as f:
		file_count = 1
		lines_per_file = sum(1 for line in f) // num_files
		f.seek(0)  # Reset file pointer to the beginning
		lines = []
		for idx, line in enumerate(f):
			lines.append(line)
			# If reached the desired number of lines per file or end of input file
			if len(lines) == lines_per_file or idx == (os.stat(input_file).st_size - 1):
				output_file = os.path.join(
					output_folder, f'{file_count}.jsonl')
				with open(output_file, 'w', encoding='utf-8') as fw:
					fw.writelines(lines)
				lines = []
				file_count += 1

# %%
def load_jsonl_to_df(file_path):
	data = []
	with open(file_path, 'r', encoding='utf-8') as file:
		for line in file:
			data.append(json.loads(line.strip()))

	df = pd.DataFrame(data)
	return df

# %%
# Load metadata
metadata_path = os.path.join(data_dir, metadata_fn)
metadata_split_path = os.path.join(data_dir, metadata_split)

# %%
split_files_num = 500
split_jsonl(metadata_path, metadata_split_path, split_files_num)

# %%
all_files = [os.path.join(metadata_split_path, fn) for fn in os.listdir(
	metadata_split_path) if os.path.isfile(os.path.join(metadata_split_path, fn))]

# %%
random_files = random.sample(all_files, 100)

# %%
metadata_df = pd.DataFrame()
columns_to_drop = ['main_category', 'features',
				   'description', 'images', 'videos', 'details',
				   'bought_together', 'subtitle', 'author']

# %%
count = 0
for fp in all_files:
	count += 1
	if os.path.isfile(fp):
		print(f"{count}. {fp}")
		df = load_jsonl_to_df(fp)
		df = df.sample(n=640, random_state=42)
		# df = df.sample(n=500, random_state=42)
		# Check if columns exist before dropping them
		columns_to_drop_existing = [
			col for col in columns_to_drop if col in df.columns]
		if columns_to_drop_existing:
			df.drop(columns=columns_to_drop_existing, inplace=True)

		# Replace non-numeric values in 'price' with NaN
		# df['price'] = pd.to_numeric(df['price'], errors='coerce')
		# # impute prices
		# median_price = df['price'].astype(float).median()
		# df['price'] = df['price'].astype(float).fillna(median_price)
		# df['price'] = (100 * df['price']).astype(int)


		# Process categories
		df['niche'] = df['categories'].apply(
			lambda x: str(x).strip('[]').split(', ')[-1])
		df['niche'] = df['niche'].apply(
			lambda x: str(x).replace('"', '').replace("'", ''))
		df.drop(columns='categories', inplace=True)

		df = df.dropna()
		# Concat splited df
		metadata_df = pd.concat([metadata_df, df], ignore_index=True)
# Out:
# 1. ./data/meta/192.jsonl
# 2. ./data/meta/276.jsonl
# 3. ./data/meta/75.jsonl
# 4. ./data/meta/266.jsonl
# 5. ./data/meta/296.jsonl
# 6. ./data/meta/311.jsonl
# 7. ./data/meta/235.jsonl
# 8. ./data/meta/449.jsonl
# 9. ./data/meta/97.jsonl
# 10. ./data/meta/491.jsonl
# 11. ./data/meta/300.jsonl
# 12. ./data/meta/419.jsonl
# 13. ./data/meta/455.jsonl
# 14. ./data/meta/202.jsonl
# 15. ./data/meta/383.jsonl
# 16. ./data/meta/423.jsonl
# 17. ./data/meta/63.jsonl
# 18. ./data/meta/190.jsonl
# 19. ./data/meta/155.jsonl
# 20. ./data/meta/416.jsonl
# 21. ./data/meta/17.jsonl
# 22. ./data/meta/222.jsonl
# 23. ./data/meta/78.jsonl
# 24. ./data/meta/489.jsonl
# 25. ./data/meta/481.jsonl
# 26. ./data/meta/210.jsonl
# 27. ./data/meta/65.jsonl
# 28. ./data/meta/287.jsonl
# 29. ./data/meta/53.jsonl
# 30. ./data/meta/188.jsonl
# 31. ./data/meta/267.jsonl
# 32. ./data/meta/209.jsonl
# 33. ./data/meta/32.jsonl
# 34. ./data/meta/281.jsonl
# 35. ./data/meta/103.jsonl
# 36. ./data/meta/178.jsonl
# 37. ./data/meta/418.jsonl
# 38. ./data/meta/117.jsonl
# 39. ./data/meta/366.jsonl
# 40. ./data/meta/34.jsonl
# 41. ./data/meta/147.jsonl
# 42. ./data/meta/411.jsonl
# 43. ./data/meta/450.jsonl
# 44. ./data/meta/327.jsonl
# 45. ./data/meta/119.jsonl
# 46. ./data/meta/4.jsonl
# 47. ./data/meta/127.jsonl
# 48. ./data/meta/297.jsonl
# 49. ./data/meta/494.jsonl
# 50. ./data/meta/437.jsonl
# 51. ./data/meta/340.jsonl
# 52. ./data/meta/350.jsonl
# 53. ./data/meta/143.jsonl
# 54. ./data/meta/351.jsonl
# 55. ./data/meta/434.jsonl
# 56. ./data/meta/223.jsonl
# 57. ./data/meta/13.jsonl
# 58. ./data/meta/231.jsonl
# 59. ./data/meta/460.jsonl
# 60. ./data/meta/7.jsonl
# 61. ./data/meta/98.jsonl
# 62. ./data/meta/31.jsonl
# 63. ./data/meta/280.jsonl
# 64. ./data/meta/168.jsonl
# 65. ./data/meta/154.jsonl
# 66. ./data/meta/244.jsonl
# 67. ./data/meta/38.jsonl
# 68. ./data/meta/424.jsonl
# 69. ./data/meta/39.jsonl
# 70. ./data/meta/346.jsonl
# 71. ./data/meta/195.jsonl
# 72. ./data/meta/161.jsonl
# 73. ./data/meta/362.jsonl
# 74. ./data/meta/415.jsonl
# 75. ./data/meta/142.jsonl
# 76. ./data/meta/185.jsonl
# 77. ./data/meta/225.jsonl
# 78. ./data/meta/484.jsonl
# 79. ./data/meta/392.jsonl
# 80. ./data/meta/40.jsonl
# 81. ./data/meta/313.jsonl
# 82. ./data/meta/182.jsonl
# 83. ./data/meta/230.jsonl
# 84. ./data/meta/356.jsonl
# 85. ./data/meta/439.jsonl
# 86. ./data/meta/320.jsonl
# 87. ./data/meta/265.jsonl
# 88. ./data/meta/197.jsonl
# 89. ./data/meta/148.jsonl
# 90. ./data/meta/469.jsonl
# 91. ./data/meta/326.jsonl
# 92. ./data/meta/404.jsonl
# 93. ./data/meta/496.jsonl
# 94. ./data/meta/292.jsonl
# 95. ./data/meta/274.jsonl
# 96. ./data/meta/458.jsonl
# 97. ./data/meta/68.jsonl
# 98. ./data/meta/428.jsonl
# 99. ./data/meta/454.jsonl
# 100. ./data/meta/219.jsonl
# 101. ./data/meta/486.jsonl
# 102. ./data/meta/329.jsonl
# 103. ./data/meta/249.jsonl
# 104. ./data/meta/11.jsonl
# 105. ./data/meta/229.jsonl
# 106. ./data/meta/478.jsonl
# 107. ./data/meta/406.jsonl
# 108. ./data/meta/465.jsonl
# 109. ./data/meta/247.jsonl
# 110. ./data/meta/77.jsonl
# 111. ./data/meta/204.jsonl
# 112. ./data/meta/334.jsonl
# 113. ./data/meta/67.jsonl
# 114. ./data/meta/27.jsonl
# 115. ./data/meta/373.jsonl
# 116. ./data/meta/15.jsonl
# 117. ./data/meta/370.jsonl
# 118. ./data/meta/339.jsonl
# 119. ./data/meta/466.jsonl
# 120. ./data/meta/113.jsonl
# 121. ./data/meta/353.jsonl
# 122. ./data/meta/175.jsonl
# 123. ./data/meta/498.jsonl
# 124. ./data/meta/144.jsonl
# 125. ./data/meta/84.jsonl
# 126. ./data/meta/456.jsonl
# 127. ./data/meta/200.jsonl
# 128. ./data/meta/87.jsonl
# 129. ./data/meta/381.jsonl
# 130. ./data/meta/131.jsonl
# 131. ./data/meta/463.jsonl
# 132. ./data/meta/495.jsonl
# 133. ./data/meta/96.jsonl
# 134. ./data/meta/319.jsonl
# 135. ./data/meta/441.jsonl
# 136. ./data/meta/497.jsonl
# 137. ./data/meta/369.jsonl
# 138. ./data/meta/21.jsonl
# 139. ./data/meta/203.jsonl
# 140. ./data/meta/46.jsonl
# 141. ./data/meta/360.jsonl
# 142. ./data/meta/123.jsonl
# 143. ./data/meta/402.jsonl
# 144. ./data/meta/338.jsonl
# 145. ./data/meta/385.jsonl
# 146. ./data/meta/316.jsonl
# 147. ./data/meta/121.jsonl
# 148. ./data/meta/447.jsonl
# 149. ./data/meta/432.jsonl
# 150. ./data/meta/389.jsonl
# 151. ./data/meta/211.jsonl
# 152. ./data/meta/358.jsonl
# 153. ./data/meta/48.jsonl
# 154. ./data/meta/129.jsonl
# 155. ./data/meta/259.jsonl
# 156. ./data/meta/20.jsonl
# 157. ./data/meta/115.jsonl
# 158. ./data/meta/81.jsonl
# 159. ./data/meta/401.jsonl
# 160. ./data/meta/480.jsonl
# 161. ./data/meta/270.jsonl
# 162. ./data/meta/291.jsonl
# 163. ./data/meta/26.jsonl
# 164. ./data/meta/294.jsonl
# 165. ./data/meta/471.jsonl
# 166. ./data/meta/54.jsonl
# 167. ./data/meta/391.jsonl
# 168. ./data/meta/477.jsonl
# 169. ./data/meta/493.jsonl
# 170. ./data/meta/237.jsonl
# 171. ./data/meta/24.jsonl
# 172. ./data/meta/400.jsonl
# 173. ./data/meta/451.jsonl
# 174. ./data/meta/207.jsonl
# 175. ./data/meta/464.jsonl
# 176. ./data/meta/317.jsonl
# 177. ./data/meta/12.jsonl
# 178. ./data/meta/365.jsonl
# 179. ./data/meta/273.jsonl
# 180. ./data/meta/304.jsonl
# 181. ./data/meta/232.jsonl
# 182. ./data/meta/215.jsonl
# 183. ./data/meta/33.jsonl
# 184. ./data/meta/488.jsonl
# 185. ./data/meta/331.jsonl
# 186. ./data/meta/66.jsonl
# 187. ./data/meta/71.jsonl
# 188. ./data/meta/368.jsonl
# 189. ./data/meta/295.jsonl
# 190. ./data/meta/344.jsonl
# 191. ./data/meta/355.jsonl
# 192. ./data/meta/252.jsonl
# 193. ./data/meta/28.jsonl
# 194. ./data/meta/111.jsonl
# 195. ./data/meta/405.jsonl
# 196. ./data/meta/324.jsonl
# 197. ./data/meta/193.jsonl
# 198. ./data/meta/141.jsonl
# 199. ./data/meta/125.jsonl
# 200. ./data/meta/421.jsonl
# 201. ./data/meta/138.jsonl
# 202. ./data/meta/412.jsonl
# 203. ./data/meta/341.jsonl
# 204. ./data/meta/62.jsonl
# 205. ./data/meta/468.jsonl
# 206. ./data/meta/429.jsonl
# 207. ./data/meta/122.jsonl
# 208. ./data/meta/435.jsonl
# 209. ./data/meta/303.jsonl
# 210. ./data/meta/462.jsonl
# 211. ./data/meta/285.jsonl
# 212. ./data/meta/246.jsonl
# 213. ./data/meta/109.jsonl
# 214. ./data/meta/224.jsonl
# 215. ./data/meta/145.jsonl
# 216. ./data/meta/255.jsonl
# 217. ./data/meta/135.jsonl
# 218. ./data/meta/94.jsonl
# 219. ./data/meta/22.jsonl
# 220. ./data/meta/382.jsonl
# 221. ./data/meta/206.jsonl
# 222. ./data/meta/499.jsonl
# 223. ./data/meta/367.jsonl
# 224. ./data/meta/137.jsonl
# 225. ./data/meta/279.jsonl
# 226. ./data/meta/88.jsonl
# 227. ./data/meta/69.jsonl
# 228. ./data/meta/107.jsonl
# 229. ./data/meta/459.jsonl
# 230. ./data/meta/227.jsonl
# 231. ./data/meta/483.jsonl
# 232. ./data/meta/201.jsonl
# 233. ./data/meta/50.jsonl
# 234. ./data/meta/310.jsonl
# 235. ./data/meta/120.jsonl
# 236. ./data/meta/196.jsonl
# 237. ./data/meta/283.jsonl
# 238. ./data/meta/5.jsonl
# 239. ./data/meta/212.jsonl
# 240. ./data/meta/492.jsonl
# 241. ./data/meta/45.jsonl
# 242. ./data/meta/345.jsonl
# 243. ./data/meta/133.jsonl
# 244. ./data/meta/37.jsonl
# 245. ./data/meta/308.jsonl
# 246. ./data/meta/18.jsonl
# 247. ./data/meta/163.jsonl
# 248. ./data/meta/359.jsonl
# 249. ./data/meta/290.jsonl
# 250. ./data/meta/240.jsonl
# 251. ./data/meta/470.jsonl
# 252. ./data/meta/376.jsonl
# 253. ./data/meta/157.jsonl
# 254. ./data/meta/425.jsonl
# 255. ./data/meta/275.jsonl
# 256. ./data/meta/384.jsonl
# 257. ./data/meta/408.jsonl
# 258. ./data/meta/169.jsonl
# 259. ./data/meta/57.jsonl
# 260. ./data/meta/83.jsonl
# 261. ./data/meta/396.jsonl
# 262. ./data/meta/56.jsonl
# 263. ./data/meta/164.jsonl
# 264. ./data/meta/242.jsonl
# 265. ./data/meta/348.jsonl
# 266. ./data/meta/337.jsonl
# 267. ./data/meta/398.jsonl
# 268. ./data/meta/438.jsonl
# 269. ./data/meta/299.jsonl
# 270. ./data/meta/238.jsonl
# 271. ./data/meta/288.jsonl
# 272. ./data/meta/173.jsonl
# 273. ./data/meta/378.jsonl
# 274. ./data/meta/395.jsonl
# 275. ./data/meta/357.jsonl
# 276. ./data/meta/8.jsonl
# 277. ./data/meta/354.jsonl
# 278. ./data/meta/236.jsonl
# 279. ./data/meta/116.jsonl
# 280. ./data/meta/403.jsonl
# 281. ./data/meta/136.jsonl
# 282. ./data/meta/112.jsonl
# 283. ./data/meta/214.jsonl
# 284. ./data/meta/282.jsonl
# 285. ./data/meta/208.jsonl
# 286. ./data/meta/172.jsonl
# 287. ./data/meta/102.jsonl
# 288. ./data/meta/218.jsonl
# 289. ./data/meta/166.jsonl
# 290. ./data/meta/213.jsonl
# 291. ./data/meta/309.jsonl
# 292. ./data/meta/114.jsonl
# 293. ./data/meta/349.jsonl
# 294. ./data/meta/70.jsonl
# 295. ./data/meta/42.jsonl
# 296. ./data/meta/198.jsonl
# 297. ./data/meta/132.jsonl
# 298. ./data/meta/199.jsonl
# 299. ./data/meta/343.jsonl
# 300. ./data/meta/409.jsonl
# 301. ./data/meta/330.jsonl
# 302. ./data/meta/433.jsonl
# 303. ./data/meta/43.jsonl
# 304. ./data/meta/410.jsonl
# 305. ./data/meta/302.jsonl
# 306. ./data/meta/444.jsonl
# 307. ./data/meta/278.jsonl
# 308. ./data/meta/93.jsonl
# 309. ./data/meta/264.jsonl
# 310. ./data/meta/128.jsonl
# 311. ./data/meta/79.jsonl
# 312. ./data/meta/23.jsonl
# 313. ./data/meta/30.jsonl
# 314. ./data/meta/19.jsonl
# 315. ./data/meta/271.jsonl
# 316. ./data/meta/3.jsonl
# 317. ./data/meta/394.jsonl
# 318. ./data/meta/183.jsonl
# 319. ./data/meta/277.jsonl
# 320. ./data/meta/35.jsonl
# 321. ./data/meta/64.jsonl
# 322. ./data/meta/152.jsonl
# 323. ./data/meta/243.jsonl
# 324. ./data/meta/1.jsonl
# 325. ./data/meta/289.jsonl
# 326. ./data/meta/335.jsonl
# 327. ./data/meta/90.jsonl
# 328. ./data/meta/361.jsonl
# 329. ./data/meta/251.jsonl
# 330. ./data/meta/41.jsonl
# 331. ./data/meta/49.jsonl
# 332. ./data/meta/16.jsonl
# 333. ./data/meta/318.jsonl
# 334. ./data/meta/453.jsonl
# 335. ./data/meta/118.jsonl
# 336. ./data/meta/191.jsonl
# 337. ./data/meta/159.jsonl
# 338. ./data/meta/298.jsonl
# 339. ./data/meta/436.jsonl
# 340. ./data/meta/162.jsonl
# 341. ./data/meta/440.jsonl
# 342. ./data/meta/448.jsonl
# 343. ./data/meta/228.jsonl
# 344. ./data/meta/6.jsonl
# 345. ./data/meta/377.jsonl
# 346. ./data/meta/293.jsonl
# 347. ./data/meta/347.jsonl
# 348. ./data/meta/106.jsonl
# 349. ./data/meta/475.jsonl
# 350. ./data/meta/393.jsonl
# 351. ./data/meta/482.jsonl
# 352. ./data/meta/176.jsonl
# 353. ./data/meta/184.jsonl
# 354. ./data/meta/431.jsonl
# 355. ./data/meta/220.jsonl
# 356. ./data/meta/9.jsonl
# 357. ./data/meta/420.jsonl
# 358. ./data/meta/325.jsonl
# 359. ./data/meta/92.jsonl
# 360. ./data/meta/426.jsonl
# 361. ./data/meta/485.jsonl
# 362. ./data/meta/286.jsonl
# 363. ./data/meta/130.jsonl
# 364. ./data/meta/388.jsonl
# 365. ./data/meta/100.jsonl
# 366. ./data/meta/371.jsonl
# 367. ./data/meta/105.jsonl
# 368. ./data/meta/476.jsonl
# 369. ./data/meta/284.jsonl
# 370. ./data/meta/110.jsonl
# 371. ./data/meta/305.jsonl
# 372. ./data/meta/380.jsonl
# 373. ./data/meta/363.jsonl
# 374. ./data/meta/29.jsonl
# 375. ./data/meta/417.jsonl
# 376. ./data/meta/445.jsonl
# 377. ./data/meta/443.jsonl
# 378. ./data/meta/260.jsonl
# 379. ./data/meta/134.jsonl
# 380. ./data/meta/153.jsonl
# 381. ./data/meta/272.jsonl
# 382. ./data/meta/336.jsonl
# 383. ./data/meta/452.jsonl
# 384. ./data/meta/95.jsonl
# 385. ./data/meta/258.jsonl
# 386. ./data/meta/234.jsonl
# 387. ./data/meta/205.jsonl
# 388. ./data/meta/387.jsonl
# 389. ./data/meta/91.jsonl
# 390. ./data/meta/217.jsonl
# 391. ./data/meta/342.jsonl
# 392. ./data/meta/446.jsonl
# 393. ./data/meta/315.jsonl
# 394. ./data/meta/269.jsonl
# 395. ./data/meta/352.jsonl
# 396. ./data/meta/85.jsonl
# 397. ./data/meta/256.jsonl
# 398. ./data/meta/372.jsonl
# 399. ./data/meta/474.jsonl
# 400. ./data/meta/76.jsonl
# 401. ./data/meta/89.jsonl
# 402. ./data/meta/165.jsonl
# 403. ./data/meta/241.jsonl
# 404. ./data/meta/124.jsonl
# 405. ./data/meta/422.jsonl
# 406. ./data/meta/174.jsonl
# 407. ./data/meta/253.jsonl
# 408. ./data/meta/80.jsonl
# 409. ./data/meta/10.jsonl
# 410. ./data/meta/414.jsonl
# 411. ./data/meta/146.jsonl
# 412. ./data/meta/82.jsonl
# 413. ./data/meta/72.jsonl
# 414. ./data/meta/257.jsonl
# 415. ./data/meta/139.jsonl
# 416. ./data/meta/14.jsonl
# 417. ./data/meta/364.jsonl
# 418. ./data/meta/442.jsonl
# 419. ./data/meta/104.jsonl
# 420. ./data/meta/51.jsonl
# 421. ./data/meta/490.jsonl
# 422. ./data/meta/74.jsonl
# 423. ./data/meta/312.jsonl
# 424. ./data/meta/328.jsonl
# 425. ./data/meta/167.jsonl
# 426. ./data/meta/500.jsonl
# 427. ./data/meta/140.jsonl
# 428. ./data/meta/323.jsonl
# 429. ./data/meta/233.jsonl
# 430. ./data/meta/186.jsonl
# 431. ./data/meta/60.jsonl
# 432. ./data/meta/47.jsonl
# 433. ./data/meta/189.jsonl
# 434. ./data/meta/386.jsonl
# 435. ./data/meta/181.jsonl
# 436. ./data/meta/321.jsonl
# 437. ./data/meta/151.jsonl
# 438. ./data/meta/187.jsonl
# 439. ./data/meta/479.jsonl
# 440. ./data/meta/261.jsonl
# 441. ./data/meta/268.jsonl
# 442. ./data/meta/245.jsonl
# 443. ./data/meta/263.jsonl
# 444. ./data/meta/221.jsonl
# 445. ./data/meta/375.jsonl
# 446. ./data/meta/250.jsonl
# 447. ./data/meta/262.jsonl
# 448. ./data/meta/58.jsonl
# 449. ./data/meta/399.jsonl
# 450. ./data/meta/55.jsonl
# 451. ./data/meta/194.jsonl
# 452. ./data/meta/413.jsonl
# 453. ./data/meta/473.jsonl
# 454. ./data/meta/36.jsonl
# 455. ./data/meta/2.jsonl
# 456. ./data/meta/61.jsonl
# 457. ./data/meta/177.jsonl
# 458. ./data/meta/158.jsonl
# 459. ./data/meta/73.jsonl
# 460. ./data/meta/390.jsonl
# 461. ./data/meta/457.jsonl
# 462. ./data/meta/397.jsonl
# 463. ./data/meta/467.jsonl
# 464. ./data/meta/427.jsonl
# 465. ./data/meta/254.jsonl
# 466. ./data/meta/44.jsonl
# 467. ./data/meta/25.jsonl
# 468. ./data/meta/333.jsonl
# 469. ./data/meta/226.jsonl
# 470. ./data/meta/156.jsonl
# 471. ./data/meta/239.jsonl
# 472. ./data/meta/59.jsonl
# 473. ./data/meta/101.jsonl
# 474. ./data/meta/160.jsonl
# 475. ./data/meta/179.jsonl
# 476. ./data/meta/108.jsonl
# 477. ./data/meta/99.jsonl
# 478. ./data/meta/301.jsonl
# 479. ./data/meta/86.jsonl
# 480. ./data/meta/170.jsonl
# 481. ./data/meta/461.jsonl
# 482. ./data/meta/307.jsonl
# 483. ./data/meta/149.jsonl
# 484. ./data/meta/180.jsonl
# 485. ./data/meta/374.jsonl
# 486. ./data/meta/52.jsonl
# 487. ./data/meta/248.jsonl
# 488. ./data/meta/322.jsonl
# 489. ./data/meta/126.jsonl
# 490. ./data/meta/150.jsonl
# 491. ./data/meta/379.jsonl
# 492. ./data/meta/314.jsonl
# 493. ./data/meta/306.jsonl
# 494. ./data/meta/430.jsonl
# 495. ./data/meta/171.jsonl
# 496. ./data/meta/216.jsonl
# 497. ./data/meta/407.jsonl
# 498. ./data/meta/472.jsonl
# 499. ./data/meta/332.jsonl
# 500. ./data/meta/487.jsonl

# %%
metadata_df['price'] = pd.to_numeric(metadata_df['price'], errors='coerce')
# check if still exist non numberic row
non_numeric_rows = metadata_df[pd.to_numeric(metadata_df['price'], errors='coerce').isnull()]

# %%
niches = list(metadata_df['niche'].unique())

# %%
niches.remove("")

# %%
imute_prices_by_niche = {}
for niche in niches:
	df = metadata_df[metadata_df['niche'] == niche]
	# # impute prices
	mean_price = df['price'].astype(float).mean()

	imute_prices_by_niche[niche] = mean_price

# %%
for niche in niches:
    niche_median_price = imute_prices_by_niche[niche]
    # Select rows where 'niche' matches the current niche
    niche_rows = metadata_df['niche'] == niche
    # Replace NaN values in 'price' column for this niche with median price
    metadata_df.loc[niche_rows, 'price'].fillna(niche_median_price, inplace=True)

# %%
out_metadata_path = "./data/preprocessed_metadata.csv"
# Write the DataFrame to a CSV file
metadata_df.to_csv(out_metadata_path, index=False)

# %%
if os.path.isdir(metadata_split_path):
	shutil.rmtree(metadata_split_path)

# %% [markdown]
# # Preprocess reviews file

# %%
import pandas as pd

# %%
reviews_df = pd.read_csv("data/Electronics.csv")

# %%
# reviews_df = reviews_df.sample(n=int(len(reviews_df) / 8), random_state=42)

# %%
len(reviews_df)

# %%
out_reviews_path = "./data/preprocessed_reviews.csv"
# Write the DataFrame to a CSV file
reviews_df.to_csv(out_reviews_path, index=False)
